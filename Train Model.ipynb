# %%
import pandas as pd
import gensim
import re
import numpy as np

# %%
headers = "country,sku_id,title,category_lvl_1,category_lvl_2,category_lvl_3,short_description, price,product_type".split(",")

# Training data
data_train = pd.read_csv("./data/training/data_train.csv", names=headers)
clarity_train = pd.read_csv("./data/training/clarity_train.labels", names=['clarity_label'])
conciseness_train = pd.read_csv("./data/training/conciseness_train.labels", names=['conciseness_label'])

data_train['clarity_label'] = clarity_train['clarity_label']
data_train['conciseness_label'] = conciseness_train['conciseness_label']

# Validation
data_validate = pd.read_csv("./data/validation/data_valid.csv", names=headers)

# %%
def repair_feature_dataframe(data_train, w2v_model, contain_label=False):
    # Title cleaning
    def clean_title(title):
        title = title.lower()
        title = title.replace("/", " / ")
        title = re.sub(r"[^A-z0-9\s-]", "", title)

        return title

    data_train['title_clean'] = data_train.title.apply(clean_title)
    
    selected_label = ['title_clean']
    if contain_label:
        selected_label += ['clarity_label', 'conciseness_label']
    data_train = data_train[selected_label]
    
    # Word2vec title
    def vector_title(title, w2v_model):
        title = title.split(" ")
        vec = np.zeros(300)
        for w in title:
            try:
                vec += w2v_model[w]
            except:
                pass

        return vec

    data_train['vector_title'] = data_train.title_clean.apply(lambda t: vector_title(t, w2v_model))
    return data_train

# %%
w2v_model = gensim.models.KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin', binary=True)

# %%
data_train = repair_feature_dataframe(data_train, w2v_model, contain_label=True)
# Out:
# /home/duyetdev/.local/lib/python2.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_validate = repair_feature_dataframe(data_validate, w2v_model, contain_label=False)

# %%
data_train
# Out:
#       country               sku_id  \
# 0          my     AD674FAASTLXANMY
# 1          my   AE068HBAA3RPRDANMY
# 2          my   AN680ELAA9VN57ANMY
# 3          my   AN957HBAAAHDF4ANMY
# 4          my     AR511HBAXNWAANMY
# 5          my     AS575ELCMZ4WANMY
# 6          my   AS727ELAA9LLV1ANMY
# 7          my   BU512HBAA4WUVTANMY
# 8          my     CL787ELAW29LANMY
# 9          my   CO633HLAABREKOANMY
# 10         my   EL802HLAA51ZZVANMY
# 11         my   EM688OTAA9H8S8ANMY
# 12         my   FE090OTAAAPW6VANMY
# 13         my   FI087ELAA7Z6D7ANMY
# 14         my     FO862HBAZ6LWANMY
# 15         my   HA543FAAAA8IHWANMY
# 16         my   JI013OTAA5FMEDANMY
# 17         my   JI733ELAA3XWA1ANMY
# 18         my   JO156ELAA6CO0MANMY
# 19         my   JO511HBAA7CGMGANMY
# 20         my     JU816FAAPKMIANMY
# 21         my   KD209HAAAA8EEEANMY
# 22         my   KE294HLAA8EBUZANMY
# 23         my   KO422HBAA8WEQ8ANMY
# 24         my     LE106ELAVO5SANMY
# 25         my   LU316ELAA8O9BQANMY
# 26         my     LY834FABEWC9ANMY
# 27         my   MO158HAAA30BBCANMY
# 28         my     MO554ELBMC5YANMY
# 29         my     MO554ELCHBVMANMY
# ...       ...                  ...
# 36253      sg  NO780ELAA30ZYYSGAMZ
# 36254      sg  NO780ELAA486CNSGAMZ
# 36255      sg  NO780ELAA4MLZ4SGAMZ
# 36256      sg    NO780ELBO5LASGAMZ
# 36257      sg  NO780FAAA1M7G5SGAMZ
# 36258      sg  NO780HLAA20RXVSGAMZ
# 36259      sg  NO780HLAA3EG41SGAMZ
# 36260      sg  NO780OTAA2MX2XSGAMZ
# 36261           Watches Sunglasses Jewellery                   Watches
# 36262           Watches Sunglasses Jewellery                   Watches
# 36263                                Cameras        Camera Accessories
# 36264                    Computers & Laptops        Network Components
# 36265  TV, Audio / Video, Gaming & Wearables            TV Accessories
# 36266                      Mobiles & Tablets               Accessories
# 36267                                Fashion                     Women
# 36268                                Fashion                     Women
# 36269                                Fashion                       Men
# 36270                                Fashion                     Women
# 36271                        Health & Beauty              Beauty Tools
# 36272                          Home & Living                Home Décor
# 36273                          Home & Living                      Bath
# 36274                          Home & Living          Home Improvement
# 36275           Watches Sunglasses Jewellery                   Watches
# 36276                        Home Appliances  Small Kitchen Appliances
# 36277                        Health & Beauty             Personal Care
# 36278                    Computers & Laptops      Computer Accessories
# 36279                        Home Appliances          Large Appliances
# 36280                    Computers & Laptops      Computer Accessories
# 36281                          Home & Living                   Bedding
# 36282  TV, Audio / Video, Gaming & Wearables       Wearable Technology
#
#                            category_lvl_3  \
# 0                             Muslim Wear
# 1                        Hand & Foot Care
# 2                      Live Sound & Stage
# 3                 Shampoos & Conditioners
# 4                      Body and Skin Care
# 5                     Traditional Laptops
# 6             Lighting & Studio Equipment
# 7                        Hand & Foot Care
# 8                     Traditional Laptops
# 9                               Tableware
# 10                               Cookware
# 11                                  Women
# 12                                  Women
# 13                      Activity Trackers
# 14                                   Eyes
# 15                                  Shoes
# 16                                    Men
# 17                            Phone Cases
# 18                        Car Accessories
# 19                 Women - Eau De Parfume
# 20                                  Women
# 21                                   Fans
# 22                               Wall Art
# 23                 Moisturizers and Cream
# 24                                    NaN
# 25                            Phone Cases
# 26                                   Bags
# 27                       Garment Steamers
# 28                            Phone Cases
# 29                            Phone Cases
# ...                                   ...
# 36253                           Batteries
# 36254               Headphones & Headsets
# 36255                                 RAM
# 36256                         Phone Cases
# 36257                            Clothing
# 36258           Hallway & Entry Furniture
# 36259                      Rugs & Carpets
# 36260                               Women
# 36261                               Women
# 36262                                Kids
# 36263  Sports & Action Camera Accessories
# 36264               Wireless USB Adapters
# 36265                                 NaN
# 36266                         Phone Cases
# 36267                            Clothing
# 36268                            Clothing
# 36269               Wallets & Accessories
# 36270                            Clothing
# 36271             Hair Styling Appliances
# 36272              Other Home Decorations
# 36273                Towels, Mats & Robes
# 36274              Housekeeping & Laundry
# 36275                                 Men
# 36276             Rice Cookers & Steamers
# 36277                           Oral Care
# 36278                           Keyboards
# 36279                  Microwaves & Ovens
# 36280                            Speakers
# 36281                  Pillows & Bolsters
# 36282                   Activity Trackers
#
#                                        short_description    price  \
# 0      <ul><li>Material : Non sheer shimmer chiffon</...    49.00
# 1      Formulated with oil-free hydrating botanicals/...   128.00
# 2      <ul> <li>150cm mini microphone compatible for ...    25.07
# 3      <ul> <li>ANMYNA Complaint Silky Set (Shampoo 5...   118.00
# 4      <ul> <li>100% Authentic</li> <li>Rrefresh and ...   114.80
# 5      <div class="prod_content"> <div class="prod_de...  2599.00
# 6      <ul> <li>1. Color Temperature: 5400K</li> <li>...   388.99
# 7      <ul> <li>Reviving like a new born baby.</li> <...    10.40
# 8      <ul style= "padding: 0px; margin: 20px 0px 0px...    29.00
# 9      <ul> <li>Genuine issued McDonald's Coca Cola m...    25.00
# 10     <ul> <li>Stainless Steel Filter</li> <li>Stain...     9.48
# 11     <ul> <li>Material: Genuine Prehnite Crystal Be...    78.00
# 12     <ul> <li>Lead and Nickle Free</li> <li>Good Qu...    15.55
# 13     <ul> <li>Accurately track all-day stats like s...   499.00
# 14     <ul> <li>Apply morning and evening&nbsp;</li> ...   120.00
# 15     <ul style="list-style-type:disc"> <li>100% Bra...    56.18
# 16     <div> <ul> <li>Gender Men's</li> <li>Movement ...    84.60
# 17     <ul> <li>Print on all sides, glossy finish</li...    30.00
# 18     <ul> <li>Item Type:Phone Holder</li> <li>Size:...    16.66
# 19     <ul> <li>100% Genuine and Authentic products</...   170.00
# 20     <ul><li>Size : 9.5cm length x 1.5cm width&nbsp...    19.00
# 21     <ul> <li>1,3,6 Hours Timer</li> <li>3 Speed Co...   278.00
# 22     <div> <ul> <li>size: 5meter x 60cm</li> <li>wi...    75.00
# 23     <ul> <li>The most popular and best aloe Vera s...    59.00
# 24     <ul> <li> &nbsp;Ideal replacement or spare bat...    32.80
# 25     <ul> <li>DESIGN: The Luowan Samsung Galaxy S7 ...    18.00
# 26     <ul style= "font-style: normal; font-variant: ...    42.00
# 27     <ul> <li>Power Rating : 1500 W</li> <li>See Th...   159.00
# 28     Opening to all connections and controls - Anti...    19.99
# 29     <ul><li>Premium look and feel</li> <li>Perfect...    29.99
# ...                                                  ...      ...
# 36253  <ul> <li>Small, portable and easy to use</li> ...     8.10
# 36254  <ul> <li>100% brand new</li> <li>High quality<...    19.90
# 36255  <ul> <li>Reasonable price</li> <li>Durable and...    45.26
# 36256  <ul> <li>100% New</li> <li>Card Slot</li> <li>...    13.77
# 36257  <ul> <li>Good Quality</li> <li>Comfortable</li...    16.59
# 36258     Good qualityConvenienceDurableFashionPractical    34.00
# 36259  <ul> <li>Diameter:42cm</li> <li>Material: Plus...     3.85
# 36260  <ul style="font-size: 15px; line-height: 27.02...     6.74
# 36261  <ul> <li>Fashionable</li> <li>Good Quality</li...    12.80
# 36262  <ul> <li>Ohsen Children Women's Girls&nbsp;</l...    12.00
# 36263  <ul> <li>C-Shape Support Mount + Top Handle Gr...    39.30
# 36264  <ul> <li>Color: Black</li> <li>Input Audio: Co...     8.53
# 36265  <ul> <li>Form Color: Black</li> <li>Material: ...     4.00
# 36266  <ul> <li>Slim and lightweight</li> <li>Made of...     9.99
# 36267  <ul><li>      Material:    Cotton Blend   </li...     9.00
# 36268  <ul> <li>Solid Bomber Jacket</li> <li>Stand Co...    24.05
# 36269  <ul> <li>High-end</li> <li>Practical</li> <li>...    19.27
# 36270  <ul> <li>Thicken warm coats</li> <li>Cotton li...    74.76
# 36271  <ul> <li>Brand New.</li> <li>High Quality.</li...     7.20
# 36272  <ul> <li>Material: Cloth + Plastic + Iron Wire...     2.79
# 36273  <ul> <li><b>Material:Polyester bottom: PVC mes...    20.80
# 36274  <ul> <li>Quality of pp + polyester material, d...     2.40
# 36275  <ul> <li>stainless steel</li> <li>for Watch 38...     8.04
# 36276  <div class="prod_content"> <div class="prod_de...   113.90
# 36277  <ul> <li>Guranteed healthier gums in 2 weeks</...   125.00
# 36278  <ul> <li>No driver needed.Blue Switches is the...    67.09
# 36279  <ul> <li>&nbsp;2 Years Warranty<br></li> <li>T...    69.00
# 36280  <ul> <li>With colorful lights on the button, l...    35.00
# 36281  <ul> <li>100% Cotton</li> <li>Safe for Sensiti...    23.00
# 36282  <ul> <li>Compatibility: requires android 4.3 o...    31.00
#
#         product_type  clarity_label  conciseness_label
# 0              local              1                  1
# 1      international              1                  1
# 2      international              1                  0
# 3              local              1                  1
# 4      international              1                  1
# 5              local              1                  1
# 6      international              1                  1
# 7      international              1                  1
# 8              local              1                  1
# 9              local              1                  1
# 10     international              1                  1
# 11             local              1                  1
# 12     international              1                  1
# 13     international              1                  1
# 14             local              1                  1
# 15     international              1                  1
# 16     international              1                  1
# 17     international              1                  1
# 18     international              0                  0
# 19     international              1                  1
# 20             local              1                  1
# 21             local              1                  1
# 22             local              1                  1
# 23             local              0                  0
# 24             local              1                  1
# 25     international              1                  1
# 26             local              1                  1
# 27             local              1                  1
# 28     international              1                  1
# 29     international              1                  1
# ...              ...            ...                ...
# 36253  international              1                  1
# 36254  international              1                  0
# 36255  international              1                  1
# 36256  international              1                  1
# 36257  international              1                  0
# 36258  international              1                  1
# 36259  international              1                  0
# 36260  international              1                  0
# 36261  international              1                  0
# 36262  international              1                  0
# 36263  international              1                  1
# 36264  international              1                  1
# 36265  international              1                  1
# 36266  international              1                  1
# 36267  international              0                  0
# 36268  international              1                  1
# 36269  international              1                  0
# 36270  international              1                  0
# 36271  international              1                  0
# 36272  international              1                  1
# 36273  international              1                  1
# 36274  international              1                  0
# 36275  international              1                  0
# 36276          local              1                  1
# 36277          local              1                  1
# 36278  international              1                  1
# 36279          local              1                  1
# 36280  international              1                  0
# 36281          local              1                  1
# 36282  international              1                  0
#
# [36283 rows x 11 columns]

# %% [markdown]
# # Checkpoint training data

# %%
# data_train.to_csv("./checkpoint/data_train.csv", index=False)

# %% [markdown]
# # SVM Model

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 1. SVC

# %%
clf_SVC_clarity = svm.SVC()
clf_SVC_conciseness = svm.SVC()


X = data_train.vector_title.tolist()
y_clarity_label = data_train.clarity_label.tolist()
y_conciseness_label = data_train.conciseness_label.tolist()
data_validate_input = data_validate.vector_title.tolist()

# clarity_label ===================
X_train, X_test, y_train, y_test = train_test_split(X, y_clarity_label, test_size=0.1, random_state=42)
clf_SVC_clarity.fit(X_train, y_train)
y_pred = clf_SVC_clarity.predict(X_test)
print 'Accuracy clf_SVC_clarity = ', accuracy_score(y_test, y_pred)
# Validation
validate_result_clarity = clf_SVC_clarity.predict(data_validate_input)

# %%
# conciseness_label ===================
X_train, X_test, y_train, y_test = train_test_split(X, y_conciseness_label, test_size=0.1, random_state=43)
clf_SVC.fit(X_train, y_train)
clf_SVC_conciseness.fit(X_train, y_train)
y_pred = clf_SVC_conciseness.predict(X_test)
print 'Accuracy clf_SVC_conciseness = ', accuracy_score(y_test, y_pred)

# Validation
validate_result_conciseness = clf_SVC_conciseness.predict(data_validate_input)
# Out:
# Accuracy clf_SVC_conciseness =  0.838523009093

# %%
np.savetxt("submit/conciseness_valid.predict", validate_result_conciseness, "%.4f")
np.savetxt("submit/clarity_valid.predict", validate_result_clarity, "%.4f")

# %% [markdown]
# ## 2. Support Vector Regression

# %%
clf_SVR = svm.SVR()
clf_SVR.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = clf_SVR.predict(X_test)
accuracy_score(y_test, y_pred.round(), normalize=False)
# Out:
# 0.94245866043093374

# %% [markdown]
# # Validation
