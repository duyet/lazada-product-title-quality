# %%
import pandas as pd
import gensim
from gensim import models

import re
import numpy as np

# %%
headers = "country,sku_id,title,category_lvl_1,category_lvl_2,category_lvl_3,short_description, price,product_type".split(",")

# Training data
data_train = pd.read_csv("./data/training/data_train.csv", names=headers)
clarity_train = pd.read_csv("./data/training/clarity_train.labels", names=['clarity_label'])
conciseness_train = pd.read_csv("./data/training/conciseness_train.labels", names=['conciseness_label'])

data_train['clarity_label'] = clarity_train['clarity_label']
data_train['conciseness_label'] = conciseness_train['conciseness_label']

# Validation
data_validate = pd.read_csv("./data/validation/data_valid.csv", names=headers)

# %%
data_validate
# Out:
#       country               sku_id  \
# 0          my     AP564ELASSTWANMY
# 1          my   BR924HBAA5B3TLANMY
# 2          my   CA673ELAA5UG3XANMY
# 3          my   DE759ELAA7QM1XANMY
# 4          my   ES802OTAABHAY8ANMY
# 5          my   HP961ELAABF7N7ANMY
# 6          my   KI402HBAA5QI06ANMY
# 7          my     MO554ELCCEXMANMY
# 8          my   NO037ELAA35QHLANMY
# 9          my   NO037ELAA5MMBPANMY
# 10         my   NO037ELAA7YNMDANMY
# 11         my   NO037ELAA83259ANMY
# 12         my   NO037FAAABR8CRANMY
# 13         my     NO037FACOVV3ANMY
# 14         my   NO037HBAA82RMCANMY
# 15         my   NO037HLAA8IF5PANMY
# 16         my   NO037OTAA72B3UANMY
# 17         my   OE702ELAA4R5D8ANMY
# 18         my   OE702ELAA8RH49ANMY
# 19         my   OE702ELAA8VE7SANMY
# 20         my     OT343TBATNHAANMY
# 21         my   RA124ELAA45U9QANMY
# 22         my   SH845FAAA626OUANMY
# 23         ph     GI768OTBF1SKANPH
# 24         ph   JE613HBAA2QAESANPH
# 25         ph   MA199ELAA5TVJPANPH
# 26         ph   MI733HAAA2QTHPANPH
# 27         ph   NO649ELAA3NRVQANPH
# 28         ph   NO649ELAA44WKFANPH
# 29         ph   NO649FAAA2LE4WANPH
# ...       ...                  ...
# 11808      ph   EP602ELAA4K7J4ANPH
# 11809      ph     JE938ELAPPJIANPH
# 11810      ph   KY927HAAA27QORANPH
# 11811      ph   LE801ELAA7FGB7ANPH
# 11812      ph   NI194OTAA1EO1ZANPH
# 11813      ph   NO649HLAA205J7ANPH
# 11814      ph   OE721ELAA5G4FQANPH
# 11815      ph   OE721ELAA628D5ANPH
# 11816      ph   OE721OTAA5NMTCANPH
# 11817      ph   SL919HLAA3OA1VANPH
# 11818      ph   UN308HAAA2D5FLANPH
# 11819      ph   VA294HLAA23A37ANPH
# 11820      ph   XI390ELAA45VU6ANPH
# 11821      ph   ZH133ELAA37D0XANPH
# 11822      sg  AK424HAAA1QUP9SGAMZ
# 11823      sg  AS575ELAA50H7KSGAMZ
# 11824      sg  BO386FAAA2I9K9SGAMZ
# 11825      sg  BO954HLAA4TZXVSGAMZ
# 11826      sg  MO937ELAA42VVISGAMZ
# 11827      sg  NO780FAAA4AFZKSGAMZ
# 11828      sg  NO780HLAA3X24RSGAMZ
# 11829      sg  NO780HLAA43BHHSGAMZ
# 11830      sg  NO780HLAA48H0WSGAMZ
# 11831      sg  NO780OTAA4GEXRSGAMZ
# 11832      sg  OE702FAAA401TNSGAMZ
# 11833      sg    OL853FAAK8SJSGAMZ
# 11834      sg  SD636FAAA41ANFSGAMZ
# 1                          Well Being
# 2                                 NaN
# 3                            Monitors
# 4                                 Men
# 5                         All-purpose
# 6                   Weight Management
# 7                         Phone Cases
# 8                                Mice
# 9                         Phone Cases
# 10                        Phone Cases
# 11                 Home Entertainment
# 12           Lingerie, Sleep & Lounge
# 13                              Women
# 14                 Makeup Accessories
# 15                     Paper Products
# 16                              Women
# 17                             Cables
# 18                        Spy Cameras
# 19                        Phone Cases
# 20                           Clothing
# 21                            Gadgets
# 22                               Bags
# 23                              Women
# 24                            Shaving
# 25                            Gadgets
# 26                              Irons
# 27                        Phone Cases
# 28                           Monitors
# 29                        Muslim Wear
# ...                               ...
# 11808                        Printers
# 11809                Lens Accessories
# 11810  Electric Kettles & Thermo Pots
# 11811           Headphones & Headsets
# 11812                           Women
# 11813       Curtains, Blinds & Shades
# 11814                     Phone Cases
# 11815                     Phone Cases
# 11816                             Men
# 11817                 Kitchen Storage
# 11818                 Vacuum Cleaners
# 11819                Outdoor Lighting
# 11820                             NaN
# 11821                             NaN
# 11822                        Freezers
# 11823                             NaN
# 11824           Wallets & Accessories
# 11825          Other Home Decorations
# 11826                     Phone Cases
# 11827                        Clothing
# 11828              Pillows & Bolsters
# 11829           Measuring & Levelling
# 11830                  Paper Products
# 11831                             Men
# 11832                            Bags
# 11833                           Women
# 11834                            Bags
# 11835                     Phone Cases
# 11836     Lighting & Studio Equipment
# 11837                     Car Cameras
#
#                                        short_description     price  \
# 0      OS X Lion<br> Intel Core i7<br> 15-inch Retina...  12550.00
# 1      <ul> <li>Traditionally used to calm the mind a...    105.00
# 2      <div> <ul> <li>18.0MP APS-C CMOS Sensor</li> <...   1588.00
# 3      <div class="prod_content"> <div class="prod_de...    565.00
# 4      <ul> <li>stainless steel case</li> <li>mineral...    279.00
# 5      <ul> <li>Model : HP Compaq 3330 Pro MT + 19" L...   1259.00
# 6      <ul> <li>Lose Weight easily and painlessly</li...     38.80
# 7      <ul> <li>Perfect and attractive decorate your ...     32.90
# 8      <ul> <li>High resolution: 800dpi Frequency for...     19.00
# 9      <div> <ul> <li>Hybrid</li> <li>Kickstand</li> ...     36.00
# 10     <ul> <li>100% Brand New And High Quality</li> ...     19.90
# 11     <div> <ul> <li>Colored plugs for easy installa...     11.58
# 12     <ul style="white-space:normal;"> <li>100% Bran...     15.00
# 13     <ul> <li>Color : Rose Red</li> <li>Jewelry Typ...     70.00
# 14     <ul> <li>Size:17.5cm(Height) x 7cm</li> <li>Ma...     24.34
# 15     <ul> <li>Color: Multi-Coloured</li> <li>Size: ...     11.64
# 16     <ul> <li>100% Brand new and high quality!</li>...     10.68
# 17     <ul> <li>Suitable for Android Phone&nbsp;</li>...     10.45
# 18     <ul> <li>New and high quality</li> <li>For a s...     67.33
# 19     <ul> <li>Material:PU + PC</li> <li>S View wind...     25.88
# 20                                                   NaN     28.00
# 21     <ul> <li style="text-align:justify">Compatible...    407.41
# 22     <ul> <li>Great for school,outdoor living and j...    145.35
# 23     <ul> <li>Hoop Earrings</li> <li>Material: Rhod...   3000.00
# 24     <ul> <li>100% brand new</li> <li>Fit for most ...    263.10
# 25     <ul> <li>Material:Chiffon</li> <li>Short sleev...   1866.31
# 26     <div class="prod_content"> <div class="prod_de...    428.00
# 27     <ul> <li>Animal pattern</li> <li>Shields the b...    400.00
# 28     <ul> <li>14.0-inch WideScreen (12"x7.4")<br></...   4707.19
# 29     <ul> <li>Easy to care</li> <li>Machine wash co...    420.00
# ...                                                  ...       ...
# 11808  <ul> <li>Function: Print, Copy, Scan</li> <li>...   7588.00
# 11809  <ul> <li>Color: Black</li> <li>It is simple, s...    275.00
# 11810  <ul> <li>1.7 liters capacity</li> <li>heat-res...    599.00
# 11811  <ul> <li>Cat Ear Headphones with Glowing Blue ...    851.00
# 11812  <ul><li>Material:Environmental copper+Purple r...    840.00
# 11813  <ul> <li>100% Brand new</li> <li>Easy to use</...    685.00
# 11814  <ul> <li>Form Color: Black</li> <li>Material: ...    437.00
# 11815  <ul class="list-paddingleft-2" style="list-sty...    606.00
# 11816  <ul> <li><strong>Material: Titanium Steel+</st...    690.00
# 11817  <ul> <li>• Suitable to store snacks, nuts, her...    649.00
# 11818  <ul> <li>Powerful hand-held vacuum cleaner</li...   1150.00
# 11819  <ul> <li>Environmental-friendly and energy sav...   1030.00
# 11820  <ul> <li>Google Play Store,Multi-language</li>...   9699.00
# 11821  <ul style="font-size: 15px;"> <li>Android 5.1 ...   2249.95
# 11822  <ul> <li>Capacity : 358L (R134a CFC Free Refri...    463.75
# 11823  <ul> <li>5.5 inches (~70.6% screen-to-body rat...    460.00
# 11824  <ul> <li>Genuine Cow Leather and waterproof</l...     22.50
# 11825  <ul> <li>Durable</li> <li>Top quality</li> <li...      9.90
# 11826  <ul> <li>Premium look and feel</li> <li>Perfec...     12.50
# 11827  <ul> <li>Material:85% Nylon, 15% Spandex</li> ...     18.00
# 11828  <ul> <li>Flocking Corn Kernels</li> <li>High q...     10.98
# 11829  <div> <ul> <li>Features: 1. any position clear...     21.00
# 11830  <div> <div> <ul> <li>Material: PU leather + kr...     10.40
# 11831  <ul> <li>100% Brand New</li> <li>High quality<...     74.44
# 11832  <ul> <li>Condition: Brand new</li> <li>Materia...     24.70
# 11833  <ul><li>Color: Ocean Blue</li><li>Jewelry Type...     13.00
# 11834  <ul> <li>The Adele Bethany&nbsp;is the perfect...     21.90
# 11835  <ul> <li>Newly designed TPU pattern adds grip ...     32.90
# 11836  <ul> <li>Instant photo studio at home or on-th...     16.30
# 11837  <ul class=""> <li class="">TV System: PAL / NT...     29.08
#
#         product_type
# 0              local
# 1              local
# 2              local
# 3              local
# 4              local
# 5              local
# 6              local
# 7      international
# 8      international
# 9      international
# 10     international
# 11     international
# 12     international
# 13     international
# 14     international
# 15     international
# 16     international
# 17     international
# 18     international
# 19     international
# 20             local
# 21             local
# 22     international
# 23             local
# 24     international
# 25     international
# 26             local
# 27     international
# 28     international
# 29     international
# ...              ...
# 11808          local
# 11809  international
# 11810          local
# 11811  international
# 11812  international
# 11813  international
# 11814  international
# 11815  international
# 11816  international
# 11817          local
# 11818          local
# 11819  international
# 11820  international
# 11821          local
# 11822          local
# 11823          local
# 11824  international
# 11825  international
# 11826  international
# 11827  international
# 11828  international
# 11829  international
# 11830  international
# 11831  international
# 11832  international
# 11833  international
# 11834          local
# 11835          local
# 11836  international
# 11837  international
#
# [11838 rows x 9 columns]

# %%
def clean_title(title):
    title = title.lower()
    title = title.replace("/", " / ")
    title = re.sub(r"[^A-z0-9\s-]", "", title)

    return title

data_train['title_clean'] = data_train.title.apply(clean_title)
selected_label = ['title_clean', 'clarity_label', 'conciseness_label']
data_train = data_train[selected_label]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-76236517b5fb> in <module>()
#       6     return title
#       7
# ----> 8 data_train['title_clean'] = data_train.title.apply(clean_title)
#       9 data_validate['title_clean'] = data_validate.title.apply(clean_title)
#      10 selected_label = ['title_clean', 'clarity_label', 'conciseness_label']
#
# /home/duyetdev/.local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'title'

# %%
data_train.head()
# Out:
#                                          title_clean  clarity_label  \
# 0        adana gallery suri square hijab  light pink              1
# 1  cuba heartbreaker eau de parfum spray 100ml  33oz              1
# 2  andoer 150cm cellphone smartphone mini dual-he...              1
# 3  anmyna complaint silky set  shampoo 520ml  con...              1
# 4  argital argiltubo green clay for face and body...              1
#
#    conciseness_label
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1

# %%
titles = data_train.title_clean.tolist()
sentences = [ models.doc2vec.LabeledSentence(
    words=s.split(" "), tags=[s.replace(" ", "_")]) for s in titles ]

# %%
model = gensim.models.Doc2Vec(size=300, window=10, min_count=5, 
                              workers=4,alpha=0.025, min_alpha=0.025)

# %%
voca = model.build_vocab(sentences)

# %%
model.iter
# Out:
# 5

# %%
for epoch in range(10):
    model.train(sentences, total_words=1000,epochs=model.iter)
    model.alpha -= 0.002  # decrease the learning rate`
    model.min_alpha = model.alpha  # fix the learning rate, no decay

# %%
model.save("model.doc2vec")

# %%
def vector_title(title, w2v_model):
    title = title.split(" ")
    vec = np.zeros(300)
    for w in title:
        try:
            vec += w2v_model.infer_vector(w)
        except:
            pass

    return vec

# %%
vector_title("xiaomi phone", model)
data_train['vector_title'] = data_train.title_clean.apply(lambda t: vector_title(t, model))
# Out:
# /home/duyetdev/.local/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_validate['title_clean'] = data_validate.title.apply(clean_title)
data_validate['vector_title'] = data_validate.title_clean.apply(lambda t: vector_title(t, model))

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
X = data_train.vector_title.tolist()
y_clarity_label = data_train.clarity_label.tolist()
y_conciseness_label = data_train.conciseness_label.tolist()

data_validate_input = data_validate.vector_title.tolist()

# %%
clf_SVC_clarity = svm.SVC()
clf_SVC_conciseness = svm.SVC()

# clarity_label ===================
# X_train, X_test, y_train, y_test = train_test_split(X, y_clarity_label, test_size=0.1, random_state=42)
# clf_SVC_clarity.fit(X_train, y_train)
print "Fitting ..."
clf_SVC_clarity.fit(X, y_clarity_label)
# y_pred = clf_SVC_clarity.predict(X_test)
# print 'Accuracy clf_SVC_clarity = ', accuracy_score(y_test, y_pred)
# Validation
print "Predict ..."
validate_result_clarity = clf_SVC_clarity.predict(data_validate_input)
np.savetxt("submit/clarity_valid.predict", validate_result_clarity, "%.4f")
# Out:
# Fitting ...
# Predict ...

# %%
# conciseness_label ===================
# X_train, X_test, y_train, y_test = train_test_split(X, y_conciseness_label, test_size=0.1, random_state=43)
# clf_SVC.fit(X_train, y_train)
# clf_SVC_clarity.fit(X_train, y_train)

print "Fitting ..."
clf_SVC_conciseness.fit(X, y_conciseness_label)
# y_pred = clf_SVC_conciseness.predict(X_test)
# print 'Accuracy clf_SVC_conciseness = ', accuracy_score(y_test, y_pred)

# Validation
print "Predict ..."
validate_result_conciseness = clf_SVC_conciseness.predict(data_validate_input)

np.savetxt("submit/conciseness_valid.predict", validate_result_conciseness, "%.4f")
# Out:
# Fitting ...
# Predict ...

# %%
model.build_vocab(it)
